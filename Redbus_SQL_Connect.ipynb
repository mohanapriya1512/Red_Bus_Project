# %%
# !pip install sqlalchemy pymysql

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# %%
#Cpmbining all the csv files into single df:

# List of CSV file paths

csv_files = ['./bus_details_jk2_csv.csv', './bus_details_kerala1_csv.csv', './bus_details_ktcl1_csv.csv',
            './bus_details_pepsu1_csv.csv','./bus_details_rsrtc1_csv.csv','./bus_details_ts1_csv.csv','./bus_details_hrtc1_csv.csv',
            './bus_details_bihar1_csv.csv','./bus_details_astc1_csv.csv','./bus_details_bengal1_csv.csv'] 

# Read the CSV files into DataFrames
dataframes = [pd.read_csv(file) for file in csv_files]

# Combine the DataFrames into one DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#       Unnamed: 0                         route_name  \
# 0              0        Jammu (j and k) to Srinagar
# 1              1        Jammu (j and k) to Srinagar
# 2              2        Jammu (j and k) to Srinagar
# 3              3        Jammu (j and k) to Srinagar
# 4              4                  Delhi to Srinagar
# ...          ...                                ...
# 4502         211  Durgapur (West Bengal) to Bankura
# 4503         212                  Siliguri to Malda
# 4504         213                  Siliguri to Malda
# 4505         215                  Siliguri to Malda
# 4506         216                    Kolkata to Suri
#
#                                              route_link  \
# 0     https://www.redbus.in/bus-tickets/jammu-to-sri...
# 1     https://www.redbus.in/bus-tickets/jammu-to-sri...
# 2     https://www.redbus.in/bus-tickets/jammu-to-sri...
# 3     https://www.redbus.in/bus-tickets/jammu-to-sri...
# ...

# %%
combined_df=combined_df.drop('Unnamed: 0',axis=1)

# %%
combined_df=combined_df.drop('Unnamed: 0.1',axis=1)

# %%
combined_df
# Out:
#                              route_name  \
# 0           Jammu (j and k) to Srinagar
# 1           Jammu (j and k) to Srinagar
# 2           Jammu (j and k) to Srinagar
# 3           Jammu (j and k) to Srinagar
# 4                     Delhi to Srinagar
# ...                                 ...
# 4502  Durgapur (West Bengal) to Bankura
# 4503                  Siliguri to Malda
# 4504                  Siliguri to Malda
# 4505                  Siliguri to Malda
# 4506                    Kolkata to Suri
#
#                                              route_link  \
# 0     https://www.redbus.in/bus-tickets/jammu-to-sri...
# 1     https://www.redbus.in/bus-tickets/jammu-to-sri...
# 2     https://www.redbus.in/bus-tickets/jammu-to-sri...
# 3     https://www.redbus.in/bus-tickets/jammu-to-sri...
# 4     https://www.redbus.in/bus-tickets/delhi-to-sri...
# ...                                                 ...
# 4502  https://www.redbus.in/bus-tickets/durgapur-to-...
# ...

# %%
myconnection=pymysql.connect(host='host',user='user',passwd='********',database='redbusdb')

# %%
#Create a table 'redbus_details' :
create_table_sql = """
CREATE TABLE redbus_details (
    id INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
    route_name TEXT,
    route_link TEXT,
    bus_name TEXT,
    bus_type TEXT,
    departing_time TIME,
    duration TEXT,
    arrival_time TIME,
    star_rating FLOAT,
    fare_price DECIMAL(7,2),
    seat_availablity INT
);
"""

print(create_table_sql)
myconnection.cursor().execute(create_table_sql)
myconnection.commit()
# Out:
# CREATE TABLE redbus_details (
#     id INT NOT NULL AUTO_INCREMENT PRIMARY KEY,
#     route_name TEXT,
#     route_link TEXT,
#     bus_name TEXT,
#     bus_type TEXT,
#     departing_time TIME,
#     duration TEXT,
#     arrival_time TIME,
#     star_rating FLOAT,
#     fare_price DECIMAL(7,2),
#     seat_availablity INT
# );

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection string :
database_url = 'mysql+pymysql://root:Saipriya1512$@127.0.0.1:3306/redbusdb'

# Create a SQLAlchemy engine
engine = create_engine(database_url)

# Table name where data will be inserted
table_name = 'redbus_details'


# Insert the combined DataFrame into the SQL table
combined_df.to_sql(table_name, engine, if_exists='append', index=False)

print(f"Data from {len(csv_files)} CSV files inserted into table '{table_name}'.")
# Out:
# Data from 10 CSV files inserted into table 'redbus_details'.
